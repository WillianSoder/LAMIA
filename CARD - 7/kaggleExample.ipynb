# %% [markdown]
# # Example Kaggle Notebook

# %%
print("TESTE")
# Out:
# TESTE

# %%
import pandas as pd

# %%
df = pd.read_csv('../input/world-population-by-country-2024/World Population by country 2024.csv')

df2 = df.loc[ df['Country'].isin(['China','United States'])]

# %%
df2.plot(x='Country', y='Density (/km2)', kind='bar', title='Density (china x EUA)')
# Out:
# <Axes: title={'center': 'Density (china x EUA)'}, xlabel='Country'>
